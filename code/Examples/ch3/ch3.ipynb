# %%
2*3+2
# Out:
# 8

# %%
result=2*3+2
result
# Out:
# 8

# %%
2**100
# Out:
# 1267650600228229401496703205376

# %%
x=1
x=1.5
y=20
z=10

# %%
x=1
y=0
x and y
# Out:
# 0

# %%
x or y
# Out:
# 1

# %%
not x
# Out:
# False

# %%
bool('Hello')
# Out:
# True

# %%
bool('')
# Out:
# False

# %%
bool(0)
# Out:
# False

# %%
bool([])
# Out:
# False

# %%
bool()
# Out:
# False

# %%
num=10
bin(num)
# Out:
# '0b1010'

# %%
oct(num)
# Out:
# '0o12'

# %%
hex(num)
# Out:
# '0xa'

# %%
0b1010
# Out:
# 10

# %%
0o12
# Out:
# 10

# %%
0xa
# Out:
# 10

# %%
'Do not worry.'
# Out:
# 'Do not worry.'

# %%
"Do not worry."
# Out:
# 'Do not worry.'

# %%
'Do "not" worry.'
# Out:
# 'Do "not" worry.'

# %%
'Don\'t worry'
# Out:
# "Don't worry"

# %%
"Do \"not\" worry."
# Out:
# 'Do "not" worry.'

# %%
str = 'Do not worry.'
str
# Out:
# 'Do not worry.'

# %%
str='Do not worry. \n About tomorrow.'
str
# Out:
# 'Do not worry. \n About tomorrow.'

# %%
print(str)
# Out:
# Do not worry.
#  About tomorrow.

# %%
path='c:\python'
path
# Out:
# 'c:\\python'

# %%
print(path)
# Out:
# c:\python

# %%
path='c:\python\name'
print(path)
# Out:
# c:\python
# ame

# %%
path=r'c:\python\name'
print(path)
# Out:
# c:\python\name

# %%
x=' Hello! '
y=' Python '
x+y*3
# Out:
# ' Hello!  Python  Python  Python '

# %%
(x+y)*3
# Out:
# ' Hello!  Python  Hello!  Python  Hello!  Python '

# %%
print((x+y)*3)
# Out:
#  Hello!  Python  Hello!  Python  Hello!  Python

# %%
len(x)
# Out:
# 8

# %%
x[-2]
# Out:
# '!'

# %%
y[0:2]
# Out:
# ' P'

# %%
y[0:3]
# Out:
# ' Py'

# %%
x==y
# Out:
# False

# %%
x!=y
# Out:
# True

# %%
s='hello python'
s.capitalize()
# Out:
# 'Hello python'

# %%
s.upper()
# Out:
# 'HELLO PYTHON'

# %%
s.lower()
# Out:
# 'hello python'

# %%
s.title()
# Out:
# 'Hello Python'

# %%
s.swapcase()
# Out:
# 'HELLO PYTHON'

# %%
s.replace('hello','hi')
# Out:
# 'hi python'

# %%
s.find('py')
# Out:
# 6

# %%
t=s.replace('hello','hi!')
t
# Out:
# 'hi! python'

# %%
t.find("py")
# Out:
# 4

# %%
s.count('o')
# Out:
# 2

# %%
s.startswith("HHH")
# Out:
# False

# %%
s.startswith('h',0)
# Out:
# True

# %%
s.endswith('n')
# Out:
# True

# %%
s.split()
# Out:
# ['hello', 'python']

# %%
s.split('p')
# Out:
# ['hello ', 'ython']

# %%
symbol='/'
str=('2016','04','14')
print(symbol.join(str))
# Out:
# 2016/04/14

# %%
s.isidentifier()
# Out:
# False

# %%
t='hello'
t.isidentifier()
# Out:
# True

# %%
u='help'
u.isidentifier()
# Out:
# True

# %%
'show123'.isalnum(), 'show'.isalnum(), '123'.isalnum()
# Out:
# (True, True, True)

# %%
'&abc123'.isalnum(), ''.isalnum(), '%---%'.isalnum()
# Out:
# (False, False, False)

# %%
'show'.isalpha(), '123'.isalpha(), 'show123'.isalpha()
# Out:
# (True, False, False)

# %%
'show'.isdigit(), '123'.isdigit(), 'show123'.isdigit()
# Out:
# (False, True, False)

# %%
'show'.isupper(), 'Show'.isupper(), 'SHOW'.isupper()
# Out:
# (False, False, True)

# %%
'show'.islower(), 'Show'.islower(), 'SHOW'.islower()
# Out:
# (True, False, False)

# %%
'Good Job'.istitle(), 'Good job'.istitle()
# Out:
# (True, False)

# %%
'show 123'.isspace(), ' '.isspace(), 'show'.isspace()
# Out:
# (False, True, False)

# %%
'show123'.strip(), 'show123'.lstrip(), 'show123'.rstrip()
# Out:
# ('show123', 'show123', 'show123')

# %%
'Good, Job'.partition(', ')
# Out:
# ('Good', ', ', 'Job')

# %%
'弟子規 聖人訓 首孝弟 次謹信'.split(' ')
# Out:
# ['弟子規', '聖人訓', '首孝弟', '次謹信']

# %%
price='100.15' 
cur='NT$'
price=cur + '100.15'
price.ljust(13,' '), price.rjust(13,'0'), price.zfill(13)
# Out:
# ('NT$100.15    ', '0000NT$100.15', '0000NT$100.15')

# %%
lis1=[30, 50, 99] 
lis1[0]
# Out:
# 30

# %%
lis1[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-73-6c9f0f165a9e> in <module>()
# ----> 1 lis1[10]
#
# IndexError: list index out of range

# %%
lis2=[10422152,'John','85.51']
score=lis2[2]
score
# Out:
# '85.51'

# %%
lis3=[[6, 3, 1], [5, 2, 4]]
total=lis3[0][0]+lis3[1][0]+lis3[0][1]+lis3[1][1]+lis3[0][2]+lis3[1][2]
total
# Out:
# 21

# %%
lis1=list(range(5, 25, 5))
lis1[:]
# Out:
# [5, 10, 15, 20]

# %%
lis1[1]
# Out:
# 10

# %%
lis1[-1]
# Out:
# 20

# %%
lis1[1:]
# Out:
# [10, 15, 20]

# %%
lis1[:-1]
# Out:
# [5, 10, 15]

# %%
lis1[1:-1]
# Out:
# [10, 15]

# %%
lis1[::-1]
# Out:
# [20, 15, 10, 5]

# %%
lis1[1::2]
# Out:
# [10, 20]

# %%
lis1=[5,10,15,20]
lis1.append(25)
lis1
# Out:
# [5, 10, 15, 20, 25]

# %%
lis1.extend([30,35])
lis1
# Out:
# [5, 10, 15, 20, 25, 30, 35]

# %%
lis1.insert(0,0)
lis1
# Out:
# [0, 5, 10, 15, 20, 25, 30, 35]

# %%
lis1.remove(35)
lis1
# Out:
# [0, 5, 10, 15, 20, 25, 30]

# %%
a=lis1.pop(3)
b=lis1.pop()
a,b
# Out:
# (15, 30)

# %%
lis1.sort()
lis1
# Out:
# [0, 5, 10, 20, 25]

# %%
lis1.sort(reverse=True)
lis1
# Out:
# [25, 20, 10, 5, 0]

# %%
lis1.reverse()
lis1
# Out:
# [0, 5, 10, 20, 25]

# %%
lis2=lis1.copy()
lis2
# Out:
# [0, 5, 10, 20, 25]

# %%
lis2.clear()
lis2
# Out:
# []

# %%
tup1=(1,3,5)
tup1[2]=100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-94-5d28f66ff6ed> in <module>()
#       1 tup1=(1,3,5)
# ----> 2 tup1[2]=100
#
# TypeError: 'tuple' object does not support item assignment

# %%
tup2=('Ironman',('Swim', 1.5), ('Bike', 40), ('Race', 10))
tup2
# Out:
# ('Ironman', ('Swim', 1.5), ('Bike', 40), ('Race', 10))

# %%
total= tup2[1][1]+ tup2[2][1]+ tup2[3][1]
total
# Out:
# 51.5

# %%
tup3=('Sports')
type(tup3)
# Out:
# str

# %%
tup4=("Sports",)
type(tup4)
# Out:
# tuple

# %%
set1={1,3,5,'a'}
set1
# Out:
# {1, 3, 5, 'a'}

# %%
set2={1,3, 5, [2,4,6]}
set2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-100-fe4c24f089c0> in <module>()
# ----> 1 set2={1,3, 5, [2,4,6]}
#       2 set2
#
# TypeError: unhashable type: 'list'

# %%
set3={1,1, 3, 5} 
set3
# Out:
# {1, 3, 5}

# %%
s={1,3,5,7,9} 
t={1,3,5}
t <= s, t.issubset(s)
# Out:
# (True, True)

# %%
s >= t, s.issuperset(t)
# Out:
# (True, True)

# %%
s.union(t), s | t
# Out:
# ({1, 3, 5, 7, 9}, {1, 3, 5, 7, 9})

# %%
s.intersection(t), s&t
# Out:
# ({1, 3, 5}, {1, 3, 5})

# %%
s.difference(t), s-t
# Out:
# ({7, 9}, {7, 9})

# %%
s.add(11)
s
# Out:
# {1, 3, 5, 7, 9, 11}

# %%
s.add(1)
s
# Out:
# {1, 3, 5, 7, 9, 11}

# %%
s.remove(11)
s
# Out:
# {1, 3, 5, 7, 9}

# %%
s.remove(100)
s
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-110-3f9aa703733d> in <module>()
# ----> 1 s.remove(100)
#       2 s
#
# KeyError: 100

# %%
s.discard(9)
s
# Out:
# {1, 3, 5, 7}

# %%
s.discard(100)
s
# Out:
# {1, 3, 5, 7}

# %%
a=s.pop()
a
# Out:
# 1

# %%
a=s.pop()
a
# Out:
# 3

# %%
s.clear()
s
# Out:
# set()

# %%
s.pop()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-116-c88c8c48122b> in <module>()
# ----> 1 s.pop()
#
# KeyError: 'pop from an empty set'

# %%
dic1={2330: ' 台積電 ', 3008: ' 大立光 ', 9999: ' 大盤指數 '}
dic1
# Out:
# {2330: ' 台積電 ', 3008: ' 大立光 ', 9999: ' 大盤指數 '}

# %%
dic1[2330]
# Out:
# ' 台積電 '

# %%
dic1[9999]=' 台股指數 '
dic1
# Out:
# {2330: ' 台積電 ', 3008: ' 大立光 ', 9999: ' 台股指數 '}

# %%
dic1[1101]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-120-ea655d82bb8f> in <module>()
# ----> 1 dic1[1101]
#
# KeyError: 1101

# %%
s={2357, 2498}
dic1=dict.fromkeys(s)
dic1
# Out:
# {2357: None, 2498: None}

# %%
dic1=dict.fromkeys(s, 100) 
dic1
# Out:
# {2357: 100, 2498: 100}

# %%
dic2={}
dic2=dic2.fromkeys(s, 200)
dic2
# Out:
# {2357: 200, 2498: 200}

# %%
value=dic2.get(2498)
value
# Out:
# 200

# %%
dic2.items()
# Out:
# dict_items([(2498, 200), (2357, 200)])

# %%
dic2.keys()
# Out:
# dict_keys([2498, 2357])

# %%
dic2.values()
# Out:
# dict_values([200, 200])

# %%
dic2.setdefault(9999)
dic2
# Out:
# {2357: 200, 2498: 200, 9999: None}

# %%
dic2[9999]=7725 
dic2
# Out:
# {2357: 200, 2498: 200, 9999: 7725}

# %%
backup=dic2.copy() 
backup
# Out:
# {2357: 200, 2498: 200, 9999: 7725}

# %%
dic3=dic2.pop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-131-789497035bd6> in <module>()
# ----> 1 dic3=dic2.pop()
#
# TypeError: pop expected at least 1 arguments, got 0

# %%
dic3=dic2.pop(2498) 
dic3
# Out:
# 200

# %%
dic2
# Out:
# {2357: 200, 9999: 7725}

# %%
dic4=dic2.pop(2498)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-134-c7616b3d71c1> in <module>()
# ----> 1 dic4=dic2.pop(2498)
#
# KeyError: 2498

# %%
new={'00632R': 21.45}
dic2.update(new) 
dic2
# Out:
# {'00632R': 21.45, 2357: 200, 9999: 7725}

# %%
dic2.update({2357: 75}) 
dic2
# Out:
# {'00632R': 21.45, 2357: 75, 9999: 7725}

# %%
dic2['yyyy']=dic2.pop(9999) 
dic2
# Out:
# {'00632R': 21.45, 2357: 75, 'yyyy': 7725}

# %%
dic2['yyyy']=dic2.pop(9999)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-138-7b4292c29273> in <module>()
# ----> 1 dic2['yyyy']=dic2.pop(9999)
#
# KeyError: 9999

# %%
del backup[9999]
backup
# Out:
# {2357: 200, 2498: 200}

# %%
del dic3 
dic3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-140-9c4ea648b837> in <module>()
#       1 del dic3
# ----> 2 dic3
#
# NameError: name 'dic3' is not defined

# %%
dic2.clear()
dic2
# Out:
# {}

# %%
str1='Good job'
tup1=(1, 1.5, 50, 50) 
lis1=[2, 40, 100, 100]
set1={3, 5, 7} 
dic1={10:'a', 20:'b'} 
len(str1), len(tup1), len(lis1), len(set1), len(dic1)
# Out:
# (8, 4, 4, 3, 2)

# %%
min(str1), min(tup1), min(lis1), min(set1), min(dic1)
# Out:
# (' ', 1, 2, 3, 10)

# %%
max(str1), max(tup1), max(lis1), max(set1), max(dic1)
# Out:
# ('o', 50, 100, 7, 20)

# %%
tup9=('a', 1.5, 50, 50) 
lis9=['b', 40, 100, 100] 
max(tup9)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-145-9856398f8ff8> in <module>()
#       1 tup9=('a', 1.5, 50, 50)
#       2 lis9=['b', 40, 100, 100]
# ----> 3 max(tup9)
#
# TypeError: '>' not supported between instances of 'float' and 'str'

# %%
min(lis9)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-146-c9892d2647d1> in <module>()
# ----> 1 min(lis9)
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
sum(str1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-147-f0a3a41c6f92> in <module>()
# ----> 1 sum(str1)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
sum(tup1), sum(lis1), sum(set1), sum(dic1)
# Out:
# (102.5, 242, 15, 30)

# %%
sorted(str1)
# Out:
# [' ', 'G', 'b', 'd', 'j', 'o', 'o', 'o']

# %%
sorted(str1, reverse=True)
# Out:
# ['o', 'o', 'o', 'j', 'd', 'b', 'G', ' ']

# %%
sorted(tup1), sorted(lis1), sorted(set1), sorted(dic1)
# Out:
# ([1, 1.5, 50, 50], [2, 40, 100, 100], [3, 5, 7], [10, 20])

# %%
str1.index('o'), tup1.index(1.5), lis1.index(100)
# Out:
# (1, 1, 2)

# %%
set1.index(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-153-494bffc1463e> in <module>()
# ----> 1 set1.index(5)
#
# AttributeError: 'set' object has no attribute 'index'

# %%
set1.index(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-154-494bffc1463e> in <module>()
# ----> 1 set1.index(5)
#
# AttributeError: 'set' object has no attribute 'index'

# %%
str1.count('o'), tup1.count(1.5), lis1.count(100)
# Out:
# (3, 1, 2)

# %%
set1.count(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-156-bd0d33904e1c> in <module>()
# ----> 1 set1.count(5)
#
# AttributeError: 'set' object has no attribute 'count'

# %%
dic1.count('a')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-157-33d3e900b8f5> in <module>()
# ----> 1 dic1.count('a')
#
# AttributeError: 'dict' object has no attribute 'count'

# %%
'o' in str1, 1 in tup1, 100 in lis1, 5 in set1, 10 in dic1
# Out:
# (True, True, True, True, True)

# %%
'a' in dic1
# Out:
# False

# %%
len(dic1) is 2, set1 is dic1
# Out:
# (True, False)

# %%
str2=str1 
tup2=tup1 
lis2=lis1
set2=set1 
dic2=dic1
str2 is str1, tup2 is tup1, lis2 is lis1, set2 is set1, dic2 is dic1
# Out:
# (True, True, True, True, True)

# %%
str1+str2, str1*2
# Out:
# ('Good jobGood job', 'Good jobGood job')

# %%
tup1+tup2, tup2*2
# Out:
# ((1, 1.5, 50, 50, 1, 1.5, 50, 50), (1, 1.5, 50, 50, 1, 1.5, 50, 50))

# %%
lis1+lis2, lis2*2
# Out:
# ([2, 40, 100, 100, 2, 40, 100, 100], [2, 40, 100, 100, 2, 40, 100, 100])

# %%
set1+set2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-165-b81546272777> in <module>()
# ----> 1 set1+set2
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
dic1+dic2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-166-25a398236827> in <module>()
# ----> 1 dic1+dic2
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
str1==str2, tup1>=tup2, lis1!=lis2, set1>set2
# Out:
# (True, True, False, False)

# %%
dic1==dic2, dic1!=dic2
# Out:
# (True, False)

# %%
dic1<=dic2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-169-d4c7a57ab7fe> in <module>()
# ----> 1 dic1<=dic2
#
# TypeError: '<=' not supported between instances of 'dict' and 'dict'
